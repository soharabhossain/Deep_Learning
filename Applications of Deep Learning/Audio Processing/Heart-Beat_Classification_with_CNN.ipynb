# %% [markdown]
# # Heart Beat Classification using CNN
#
# Cardiovascular diseases are one of the leading causes of death worldwide according to WHO. Therefore, being able to detect abnormalities in heartbeats is an important task.
#
# Out motivation here is to be able to automatically classify and distinguish normal heartbeats from abnormal ones.
#
# The proposed solution is a DL model that can classify real heart audio (also known as “beat classification”) into one of multiple categories: **Normal, Extrahls, Murmur, Artifact or Unlabeled.**
#
# Heartbeats consist of 2 consecutive noises called ‘lub’ and ‘dub’ which are produced due to the heart movements.
# These noises are of varying frequencies and occur in close proximity in normal situations.
#
# We aim to use CNN to classify these heartbeats into the aforementioned classes.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ## Download a CSV with Audio Metadata

# %%
# !wget https://www.dropbox.com/s/pf2vls3bso2vhjr/set_a.csv
# Out:
# --2021-06-02 06:34:12--  https://www.dropbox.com/s/pf2vls3bso2vhjr/set_a.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/pf2vls3bso2vhjr/set_a.csv [following]
# --2021-06-02 06:34:13--  https://www.dropbox.com/s/raw/pf2vls3bso2vhjr/set_a.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc611d5f296a30b4ea8691afd61c.dl.dropboxusercontent.com/cd/0/inline/BPr0GrC7mTWRJvl4SRUnBY69--CrVXBE2pauvWPMYtgKdTAXWwrqdfP5-w0dufl82t1q0kUri8rlgqmicCu7TZSNxLrc-dAXZvjJtZ5kQP6d7U1IabgAFOp-z8X7uSQUPfBzlvVBbWosrNJ1rwAnz-3u/file# [following]
# --2021-06-02 06:34:13--  https://uc611d5f296a30b4ea8691afd61c.dl.dropboxusercontent.com/cd/0/inline/BPr0GrC7mTWRJvl4SRUnBY69--CrVXBE2pauvWPMYtgKdTAXWwrqdfP5-w0dufl82t1q0kUri8rlgqmicCu7TZSNxLrc-dAXZvjJtZ5kQP6d7U1IabgAFOp-z8X7uSQUPfBzlvVBbWosrNJ1rwAnz-3u/file
# Resolving uc611d5f296a30b4ea8691afd61c.dl.dropboxusercontent.com (uc611d5f296a30b4ea8691afd61c.dl.dropboxusercontent.com)... 162.125.64.15, 2620:100:6020:15::a27d:400f
# Connecting to uc611d5f296a30b4ea8691afd61c.dl.dropboxusercontent.com (uc611d5f296a30b4ea8691afd61c.dl.dropboxusercontent.com)|162.125.64.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7031 (6.9K) [text/plain]
# Saving to: ‘set_a.csv’
#
# set_a.csv           100%[===================>]   6.87K  --.-KB/s    in 0s
#
# 2021-06-02 06:34:14 (411 MB/s) - ‘set_a.csv’ saved [7031/7031]

# %% [markdown]
# ## Download a ZIP file containing the actual Audio as WAV Files

# %%
# !wget https://www.dropbox.com/s/d2wgk8j0wsye2ab/set_a.zip
# Out:
# --2021-06-02 06:34:14--  https://www.dropbox.com/s/d2wgk8j0wsye2ab/set_a.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/d2wgk8j0wsye2ab/set_a.zip [following]
# --2021-06-02 06:34:14--  https://www.dropbox.com/s/raw/d2wgk8j0wsye2ab/set_a.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com/cd/0/inline/BPp8jfL0oBxKfkkBZUUPtKlei9B8QpoiuKvoKMv6Mkx0FxCiRJSjYKL0xEdBv7Sf1uMRvflCDXezjxwDRPKTz2Zo1RntYnAb6vgDNSL2BZLC_98q2y4es0_LE0FTawkS0NI77vPx8dJndNGnpCjWLbLj/file# [following]
# --2021-06-02 06:34:15--  https://ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com/cd/0/inline/BPp8jfL0oBxKfkkBZUUPtKlei9B8QpoiuKvoKMv6Mkx0FxCiRJSjYKL0xEdBv7Sf1uMRvflCDXezjxwDRPKTz2Zo1RntYnAb6vgDNSL2BZLC_98q2y4es0_LE0FTawkS0NI77vPx8dJndNGnpCjWLbLj/file
# Resolving ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com (ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com)... 162.125.64.15, 2620:100:6020:15::a27d:400f
# Connecting to ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com (ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com)|162.125.64.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BPrvWeypyFMxIp1Ixf8AcgEmJc-8QaRIlJSsWPfkZzaeqkW9BK2Dt2xeCmUXeQ1TsS9GVrW7WZwQTDECt5C4ZGCja-JelpxSdW8Iz6zEGdcxG8zsQn_IQkHKJ47m-6pZCLBUthuj-JRWRpc10tMZb7ntfqd8iJ6ZRTh8HsPnDMHyM860BLINfKv6V4SA7Toj-NfS358lU7mFY-m60pK1Zt0GSNqb9RFL_zHM5XC88sacRpHa6aWTQvBiFq6abUDfgwRq_2nkH0YYSc_2o3zH81dl2tw-qX4kSCfR_ZWodB5mSMEGfPWhdCp6kl0Doy43bJxkEaV8rUrC4nVXGthva8tMweWIoxLsQ-VOJhy5NGs26uM4ZfgHEiMD3eqUoQ7OUPI/file [following]
# --2021-06-02 06:34:15--  https://ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com/cd/0/inline2/BPrvWeypyFMxIp1Ixf8AcgEmJc-8QaRIlJSsWPfkZzaeqkW9BK2Dt2xeCmUXeQ1TsS9GVrW7WZwQTDECt5C4ZGCja-JelpxSdW8Iz6zEGdcxG8zsQn_IQkHKJ47m-6pZCLBUthuj-JRWRpc10tMZb7ntfqd8iJ6ZRTh8HsPnDMHyM860BLINfKv6V4SA7Toj-NfS358lU7mFY-m60pK1Zt0GSNqb9RFL_zHM5XC88sacRpHa6aWTQvBiFq6abUDfgwRq_2nkH0YYSc_2o3zH81dl2tw-qX4kSCfR_ZWodB5mSMEGfPWhdCp6kl0Doy43bJxkEaV8rUrC4nVXGthva8tMweWIoxLsQ-VOJhy5NGs26uM4ZfgHEiMD3eqUoQ7OUPI/file
# Reusing existing connection to ucf468142083c8aa56387e0fc0a1.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 85254434 (81M) [application/zip]
# Saving to: ‘set_a.zip’
#
# set_a.zip           100%[===================>]  81.30M  21.5MB/s    in 4.2s
#
# 2021-06-02 06:34:20 (19.6 MB/s) - ‘set_a.zip’ saved [85254434/85254434]

# %% [markdown]
# Unzipping this file creates a directory 'audio' inside the current folder and unzips the wav audio files (containing audio of different heart-beat sounds).

# %%
# !unzip set_a.zip -d audio
# Out:
# Archive:  set_a.zip
#   inflating: audio/artifact__201012172012.wav
#   inflating: audio/artifact__201105040918.wav
#   inflating: audio/artifact__201105041959.wav
#   inflating: audio/artifact__201105051017.wav
#   inflating: audio/artifact__201105060108.wav
#   inflating: audio/artifact__201105061143.wav
#   inflating: audio/artifact__201105190800.wav
#   inflating: audio/artifact__201105280851.wav
#   inflating: audio/artifact__201106010559.wav
#   inflating: audio/artifact__201106010602.wav
#   inflating: audio/artifact__201106021541.wav
#   inflating: audio/artifact__201106030612.wav
#   inflating: audio/artifact__201106031558.wav
#   inflating: audio/artifact__201106040722.wav
#   inflating: audio/artifact__201106040933.wav
#   inflating: audio/artifact__201106040947.wav
#   inflating: audio/artifact__201106041452.wav
#   inflating: audio/artifact__201106050353.wav
#   inflating: audio/artifact__201106061233.wav
#   inflating: audio/artifact__201106070537.wav
#   inflating: audio/artifact__201106070949.wav
#   inflating: audio/artifact__201106101314.wav
#   inflating: audio/artifact__201106101955.wav
#   inflating: audio/artifact__201106110909.wav
#   inflating: audio/artifact__201106111119.wav
#   inflating: audio/artifact__201106121242.wav
#   inflating: audio/artifact__201106121445.wav
#   inflating: audio/artifact__201106131834.wav
#   inflating: audio/artifact__201106131835.wav
#   inflating: audio/artifact__201106141701.wav
#   inflating: audio/artifact__201106161016.wav
#   inflating: audio/artifact__201106161019.wav
#   inflating: audio/artifact__201106161219.wav
#   inflating: audio/artifact__201106171003.wav
#   inflating: audio/artifact__201106190520.wav
#   inflating: audio/artifact__201106211041.wav
#   inflating: audio/artifact__201106211430.wav
#   inflating: audio/artifact__201106212112.wav
#   inflating: audio/artifact__201106220340.wav
#   inflating: audio/artifact__201106221254.wav
#   inflating: audio/Aunlabelledtest__201012172010.wav
#   inflating: audio/Aunlabelledtest__201101051105.wav
#   inflating: audio/Aunlabelledtest__201101061552.wav
#   inflating: audio/Aunlabelledtest__201101091156.wav
#   inflating: audio/Aunlabelledtest__201101110659.wav
#   inflating: audio/Aunlabelledtest__201101152256.wav
#   inflating: audio/Aunlabelledtest__201101220549.wav
#   inflating: audio/Aunlabelledtest__201101241434.wav
#   inflating: audio/Aunlabelledtest__201102081033.wav
#   inflating: audio/Aunlabelledtest__201102081045.wav
#   inflating: audio/Aunlabelledtest__201102200848.wav
#   inflating: audio/Aunlabelledtest__201103011036.wav
#   inflating: audio/Aunlabelledtest__201103140236.wav
#   inflating: audio/Aunlabelledtest__201103170122.wav
#   inflating: audio/Aunlabelledtest__201103200518.wav
#   inflating: audio/Aunlabelledtest__201103201314.wav
#   inflating: audio/Aunlabelledtest__201103232251.wav
#   inflating: audio/Aunlabelledtest__201103241336.wav
#   inflating: audio/Aunlabelledtest__201104012144.wav
#   inflating: audio/Aunlabelledtest__2011040239.wav
#   inflating: audio/Aunlabelledtest__201105011546.wav
#   inflating: audio/Aunlabelledtest__20110501548.wav
#   inflating: audio/Aunlabelledtest__201105031730.wav
#   inflating: audio/Aunlabelledtest__201106010807.wav
#   inflating: audio/Aunlabelledtest__201106030607.wav
#   inflating: audio/Aunlabelledtest__201106031556.wav
#   inflating: audio/Aunlabelledtest__201106040930.wav
#   inflating: audio/Aunlabelledtest__201106061104.wav
#   inflating: audio/Aunlabelledtest__201106061215.wav
#   inflating: audio/Aunlabelledtest__201106100606.wav
#   inflating: audio/Aunlabelledtest__201106111419.wav
#   inflating: audio/Aunlabelledtest__201106120928.wav
#   inflating: audio/Aunlabelledtest__201106130440.wav
#   inflating: audio/Aunlabelledtest__201106150614.wav
#   inflating: audio/Aunlabelledtest__201106170857.wav
#   inflating: audio/Aunlabelledtest__201106171155.wav
#   inflating: audio/Aunlabelledtest__201106191034.wav
#   inflating: audio/Aunlabelledtest__201106211725.wav
#   inflating: audio/Aunlabelledtest__201106212102.wav
#   inflating: audio/Aunlabelledtest__201108011111.wav
#   inflating: audio/Aunlabelledtest__201108011113.wav
#   inflating: audio/Aunlabelledtest__201108011116.wav
#   inflating: audio/Aunlabelledtest__201108011117.wav
#   inflating: audio/Aunlabelledtest__201108222222.wav
#   inflating: audio/Aunlabelledtest__201108222225.wav
#   inflating: audio/Aunlabelledtest__201108222228.wav
#   inflating: audio/Aunlabelledtest__201108222234.wav
#   inflating: audio/Aunlabelledtest__201108222241.wav
#   inflating: audio/Aunlabelledtest__201108222244.wav
#   inflating: audio/Aunlabelledtest__201108222247.wav
#   inflating: audio/Aunlabelledtest__201108222254.wav
#   inflating: audio/Aunlabelledtest__201108222257.wav
#   inflating: audio/extrahls__201101070953.wav
#   inflating: audio/extrahls__201101091153.wav
#   inflating: audio/extrahls__201101152255.wav
#   inflating: audio/extrahls__201101160804.wav
#   inflating: audio/extrahls__201101160808.wav
#   inflating: audio/extrahls__201101161027.wav
#   inflating: audio/extrahls__201101241423.wav
#   inflating: audio/extrahls__201101241433.wav
#   inflating: audio/extrahls__201102070251.wav
#   inflating: audio/extrahls__201102071835.wav
#   inflating: audio/extrahls__201102241217.wav
#   inflating: audio/extrahls__201103150114.wav
#   inflating: audio/extrahls__201103170134.wav
#   inflating: audio/extrahls__201103182227.wav
#   inflating: audio/extrahls__201103200218.wav
#   inflating: audio/extrahls__201104021355.wav
#   inflating: audio/extrahls__201104140118.wav
#   inflating: audio/extrahls__201104270458.wav
#   inflating: audio/extrahls__201104270459.wav
#   inflating: audio/murmur__201101051104.wav
#   inflating: audio/murmur__201101051108.wav
#   inflating: audio/murmur__201101051114.wav
#   inflating: audio/murmur__201101180902.wav
#   inflating: audio/murmur__201102051443.wav
#   inflating: audio/murmur__201102052338.wav
#   inflating: audio/murmur__201103291548.wav
#   inflating: audio/murmur__201104021355.wav
#   inflating: audio/murmur__201104241315.wav
#   inflating: audio/murmur__201104291843.wav
#   inflating: audio/murmur__201106141148.wav
#   inflating: audio/murmur__201108222221.wav
#   inflating: audio/murmur__201108222223.wav
#   inflating: audio/murmur__201108222224.wav
#   inflating: audio/murmur__201108222226.wav
#   inflating: audio/murmur__201108222227.wav
#   inflating: audio/murmur__201108222231.wav
#   inflating: audio/murmur__201108222232.wav
#   inflating: audio/murmur__201108222233.wav
#   inflating: audio/murmur__201108222235.wav
#   inflating: audio/murmur__201108222236.wav
#   inflating: audio/murmur__201108222237.wav
#   inflating: audio/murmur__201108222238.wav
#   inflating: audio/murmur__201108222242.wav
#   inflating: audio/murmur__201108222243.wav
#   inflating: audio/murmur__201108222245.wav
#   inflating: audio/murmur__201108222246.wav
#   inflating: audio/murmur__201108222248.wav
#   inflating: audio/murmur__201108222251.wav
#   inflating: audio/murmur__201108222252.wav
#   inflating: audio/murmur__201108222253.wav
#   inflating: audio/murmur__201108222255.wav
#   inflating: audio/murmur__201108222256.wav
#   inflating: audio/murmur__201108222258.wav
#   inflating: audio/normal__201101070538.wav
#   inflating: audio/normal__201101151127.wav
#   inflating: audio/normal__201102081152.wav
#   inflating: audio/normal__201102081321.wav
#   inflating: audio/normal__201102201230.wav
#   inflating: audio/normal__201102260502.wav
#   inflating: audio/normal__201102270940.wav
#   inflating: audio/normal__201103090635.wav
#   inflating: audio/normal__201103101140.wav
#   inflating: audio/normal__201103140132.wav
#   inflating: audio/normal__201103140135.wav
#   inflating: audio/normal__201103140822.wav
#   inflating: audio/normal__201103151912.wav
#   inflating: audio/normal__201103170121.wav
#   inflating: audio/normal__201103221214.wav
#   inflating: audio/normal__201104122156.wav
#   inflating: audio/normal__201104141251.wav
#   inflating: audio/normal__201105011626.wav
#   inflating: audio/normal__201105021654.wav
#   inflating: audio/normal__201105021804.wav
#   inflating: audio/normal__201105151450.wav
#   inflating: audio/normal__201106111136.wav
#   inflating: audio/normal__201106141148.wav
#   inflating: audio/normal__201106151236.wav
#   inflating: audio/normal__201106210943.wav
#   inflating: audio/normal__201106221418.wav
#   inflating: audio/normal__201106221450.wav
#   inflating: audio/normal__201108011112.wav
#   inflating: audio/normal__201108011114.wav
#   inflating: audio/normal__201108011115.wav
#   inflating: audio/normal__201108011118.wav

# %%
import os
import pickle
from glob import iglob
import numpy as np

#LibROSA is a python package for music and audio analysis
import librosa

# %%
DATA_AUDIO_DIR = './audio'
TARGET_SR = 8000
OUTPUT_DIR = './output'
OUTPUT_DIR_TRAIN = os.path.join(OUTPUT_DIR, 'train')
OUTPUT_DIR_TEST = os.path.join(OUTPUT_DIR, 'test')
AUDIO_LENGTH = 10000

# %%
os.makedirs('/content/output/train/')
os.makedirs('/content/output/test/')

# %% [markdown]
# ## Put Label Index to each Category

# %%
class_ids = {
    'normal': 0,
    'murmur': 1,
    'extrahls': 2,
    'artifact': 3,
    'unlabelled': 4,
}

# %% [markdown]
# ### Read Category/Labels from the File Names

# %%
def extract_class_id(wav_filename):
    if 'normal' in wav_filename:
        return class_ids.get('normal')
    elif 'murmur' in wav_filename:
        return class_ids.get('murmur')
    elif 'extrahls' in wav_filename:
        return class_ids.get('extrahls')
    elif 'artifact' in wav_filename:
        return class_ids.get('artifact')
    elif 'unlabelled' in wav_filename:
        return class_ids.get('unlabelled')
    else:
        return class_ids.get('unlabelled')

# %% [markdown]
# ## Load the Audio from the WAV File

# %%
# Load an audio file as a floating point time series.
# Audio will be automatically resampled to the given rate (default sr=22050).
# To preserve the native sampling rate of the file, use sr=None.
def read_audio_from_filename(filename, target_sr):
    audio, _ = librosa.load(filename, sr=target_sr, mono=True)
    audio = audio.reshape(-1, 1)
    return audio

# %% [markdown]
# ### Custom Function for Audio Formatting

# %%
def convert_data():
    for i, wav_filename in enumerate(iglob(os.path.join(DATA_AUDIO_DIR, '**/**.wav'), recursive=True)):
        class_id = extract_class_id(wav_filename)
        audio_buf = read_audio_from_filename(wav_filename, target_sr=TARGET_SR)
       
        # Normalize mean 0, variance 1
        audio_buf = (audio_buf - np.mean(audio_buf)) / np.std(audio_buf)
        original_length = len(audio_buf)
        print(i, wav_filename, original_length, np.round(np.mean(audio_buf), 4), np.std(audio_buf))
        if original_length < AUDIO_LENGTH:
            audio_buf = np.concatenate((audio_buf, np.zeros(shape=(AUDIO_LENGTH - original_length, 1))))
            print('PAD New length =', len(audio_buf))
        elif original_length > AUDIO_LENGTH:
            audio_buf = audio_buf[0:AUDIO_LENGTH]
            print('CUT New length =', len(audio_buf))

        output_folder = OUTPUT_DIR_TRAIN
        if i // 10 == 0:
            output_folder = OUTPUT_DIR_TEST

        output_filename = os.path.join(output_folder, str(i) + '.pkl')

        out = {'class_id': class_id,
               'audio': audio_buf,
               'sr': TARGET_SR}
        w=open(output_filename,'wb')
        pickle.dump(out,w)
        w.close()

# %%
convert_data()
# Out:
# 0 ./audio/Aunlabelledtest__201103011036.wav 72000 0.0 0.9999999
# CUT New length = 10000
# 1 ./audio/artifact__201106040722.wav 72000 0.0 1.0
# CUT New length = 10000
# 2 ./audio/extrahls__201103200218.wav 72000 0.0 1.0
# CUT New length = 10000
# 3 ./audio/normal__201102270940.wav 72000 -0.0 1.0
# CUT New length = 10000
# 4 ./audio/extrahls__201101152255.wav 64210 -0.0 1.0000001
# CUT New length = 10000
# 5 ./audio/Aunlabelledtest__20110501548.wav 72000 0.0 1.0
# CUT New length = 10000
# 6 ./audio/normal__201101151127.wav 72000 -0.0 1.0000001
# CUT New length = 10000
# 7 ./audio/Aunlabelledtest__201106150614.wav 72000 0.0 0.9999999
# CUT New length = 10000
# 8 ./audio/murmur__201108222223.wav 63485 -0.0 0.99999994
# CUT New length = 10000
# 9 ./audio/murmur__201108222252.wav 63485 0.0 1.0
# CUT New length = 10000
# 10 ./audio/artifact__201105280851.wav 72000 -0.0 1.0
# CUT New length = 10000
# 11 ./audio/artifact__201106010602.wav 72000 0.0 1.0
# CUT New length = 10000
# 12 ./audio/Aunlabelledtest__201106111419.wav 72000 -0.0 0.9999999
# CUT New length = 10000
# 13 ./audio/murmur__201103291548.wav 60034 -0.0 1.0
# CUT New length = 10000
# 14 ./audio/murmur__201108222246.wav 63485 0.0 1.0
# CUT New length = 10000
# 15 ./audio/Aunlabelledtest__201103241336.wav 63376 0.0 0.99999994
# CUT New length = 10000
# 16 ./audio/Aunlabelledtest__201106030607.wav 72000 0.0 1.0
# CUT New length = 10000
# 17 ./audio/normal__201103140822.wav 64112 -0.0 1.0
# CUT New length = 10000
# 18 ./audio/Aunlabelledtest__201106212102.wav 72000 0.0 1.0
# CUT New length = 10000
# 19 ./audio/murmur__201108222221.wav 63485 -0.0 1.0000001
# CUT New length = 10000
# 20 ./audio/murmur__201101180902.wav 64276 0.0 1.0
# CUT New length = 10000
# 21 ./audio/Aunlabelledtest__201106170857.wav 72000 0.0 1.0
# CUT New length = 10000
# 22 ./audio/artifact__201106171003.wav 72000 0.0 1.0
# CUT New length = 10000
# 23 ./audio/normal__201105151450.wav 60301 -0.0 0.99999994
# CUT New length = 10000
# 24 ./audio/Aunlabelledtest__201108011117.wav 63485 0.0 1.0
# CUT New length = 10000
# 25 ./audio/murmur__201108222245.wav 63485 0.0 1.0
# CUT New length = 10000
# 26 ./audio/Aunlabelledtest__201102081045.wav 68925 0.0 0.99999994
# CUT New length = 10000
# 27 ./audio/murmur__201108222236.wav 63485 0.0 1.0
# CUT New length = 10000
# 28 ./audio/murmur__201101051114.wav 71073 -0.0 0.99999994
# CUT New length = 10000
# 29 ./audio/murmur__201108222251.wav 63485 0.0 1.0
# CUT New length = 10000
# 30 ./audio/artifact__201106190520.wav 72000 -0.0 0.99999994
# CUT New length = 10000
# 31 ./audio/artifact__201106030612.wav 72000 0.0 1.0000001
# CUT New length = 10000
# 32 ./audio/normal__201108011112.wav 63485 0.0 0.99999994
# CUT New length = 10000
# 33 ./audio/extrahls__201104140118.wav 15580 -0.0 0.99999994
# CUT New length = 10000
# 34 ./audio/artifact__201106070537.wav 72000 -0.0 1.0
# CUT New length = 10000
# 35 ./audio/artifact__201106161016.wav 72000 0.0 1.0
# CUT New length = 10000
# 36 ./audio/Aunlabelledtest__201105011546.wav 72000 -0.0 1.0
# CUT New length = 10000
# 37 ./audio/normal__201103090635.wav 64112 -0.0 1.0
# CUT New length = 10000
# 38 ./audio/normal__201102201230.wav 72000 0.0 1.0
# CUT New length = 10000
# 39 ./audio/Aunlabelledtest__201106130440.wav 72000 -0.0 1.0
# CUT New length = 10000
# 40 ./audio/extrahls__201101241423.wav 72000 -0.0 1.0
# CUT New length = 10000
# 41 ./audio/Aunlabelledtest__201106061104.wav 72000 0.0 1.0
# CUT New length = 10000
# 42 ./audio/Aunlabelledtest__201106100606.wav 72000 0.0 1.0
# CUT New length = 10000
# 43 ./audio/murmur__201104021355.wav 7491 0.0 0.99999994
# PAD New length = 10000
# 44 ./audio/murmur__201108222243.wav 63485 -0.0 0.99999994
# CUT New length = 10000
# 45 ./audio/Aunlabelledtest__201108222254.wav 63485 0.0 1.0
# CUT New length = 10000
# 46 ./audio/extrahls__201101160808.wav 49337 -0.0 1.0
# CUT New length = 10000
# 47 ./audio/murmur__201108222258.wav 63485 -0.0 1.0
# CUT New length = 10000
# 48 ./audio/extrahls__201101091153.wav 72000 0.0 1.0
# CUT New length = 10000
# 49 ./audio/murmur__201106141148.wav 47733 -0.0 0.99999994
# CUT New length = 10000
# 50 ./audio/normal__201108011118.wav 63485 0.0 0.99999994
# CUT New length = 10000
# 51 ./audio/Aunlabelledtest__201101051105.wav 63088 -0.0 0.99999994
# CUT New length = 10000
# 52 ./audio/artifact__201106070949.wav 72000 0.0 1.0
# CUT New length = 10000
# 53 ./audio/Aunlabelledtest__201108011111.wav 63485 -0.0 1.0
# CUT New length = 10000
# 54 ./audio/normal__201106151236.wav 62173 -0.0 1.0
# CUT New length = 10000
# 55 ./audio/Aunlabelledtest__201108011113.wav 63485 0.0 1.0
# CUT New length = 10000
# 56 ./audio/artifact__201106111119.wav 72000 0.0 1.0
# CUT New length = 10000
# 57 ./audio/Aunlabelledtest__201106010807.wav 72000 0.0 1.0
# CUT New length = 10000
# 58 ./audio/normal__201104122156.wav 72000 -0.0 1.0
# CUT New length = 10000
# 59 ./audio/extrahls__201101161027.wav 47646 -0.0 1.0
# CUT New length = 10000
# 60 ./audio/extrahls__201101160804.wav 56140 0.0 0.99999994
# CUT New length = 10000
# 61 ./audio/Aunlabelledtest__201101061552.wav 47800 0.0 1.0
# CUT New length = 10000
# 62 ./audio/Aunlabelledtest__201105031730.wav 60702 -0.0 1.0
# CUT New length = 10000
# 63 ./audio/extrahls__201102071835.wav 62909 -0.0 1.0
# CUT New length = 10000
# 64 ./audio/artifact__201105051017.wav 72000 0.0 1.0
# CUT New length = 10000
# 65 ./audio/normal__201104141251.wav 61104 -0.0 1.0000001
# CUT New length = 10000
# 66 ./audio/artifact__201106041452.wav 72000 -0.0 1.0
# CUT New length = 10000
# 67 ./audio/Aunlabelledtest__201101110659.wav 60569 0.0 1.0
# CUT New length = 10000
# 68 ./audio/Aunlabelledtest__201101241434.wav 72000 0.0 1.0
# CUT New length = 10000
# 69 ./audio/artifact__201106101314.wav 72000 -0.0 1.0
# CUT New length = 10000
# 70 ./audio/normal__201105021804.wav 72000 -0.0 1.0000001
# CUT New length = 10000
# 71 ./audio/Aunlabelledtest__201108222222.wav 63485 0.0 1.0
# CUT New length = 10000
# 72 ./audio/murmur__201108222227.wav 63485 0.0 0.99999994
# CUT New length = 10000
# 73 ./audio/Aunlabelledtest__201106211725.wav 52212 -0.0 1.0
# CUT New length = 10000
# 74 ./audio/normal__201106210943.wav 46797 0.0 1.0
# CUT New length = 10000
# 75 ./audio/murmur__201108222255.wav 63485 0.0 1.0
# CUT New length = 10000
# 76 ./audio/normal__201106221450.wav 72000 -0.0 1.0
# CUT New length = 10000
# 77 ./audio/artifact__201106031558.wav 72000 0.0 1.0000001
# CUT New length = 10000
# 78 ./audio/artifact__201105040918.wav 72000 0.0 1.0
# CUT New length = 10000
# 79 ./audio/murmur__201108222238.wav 63485 -0.0 0.99999994
# CUT New length = 10000
# 80 ./audio/normal__201103151912.wav 72000 -0.0 0.99999994
# CUT New length = 10000
# 81 ./audio/artifact__201106220340.wav 72000 -0.0 1.0
# CUT New length = 10000
# 82 ./audio/Aunlabelledtest__201106031556.wav 72000 0.0 1.0
# CUT New length = 10000
# 83 ./audio/Aunlabelledtest__201108222234.wav 63485 0.0 1.0
# CUT New length = 10000
# 84 ./audio/murmur__201101051108.wav 71073 0.0 1.0000001
# CUT New length = 10000
# 85 ./audio/murmur__201104291843.wav 38615 0.0 1.0
# CUT New length = 10000
# 86 ./audio/normal__201103170121.wav 64246 0.0 1.0
# CUT New length = 10000
# 87 ./audio/Aunlabelledtest__201108222247.wav 63485 0.0 1.0
# CUT New length = 10000
# 88 ./audio/artifact__201105061143.wav 72000 0.0 1.0
# CUT New length = 10000
# 89 ./audio/artifact__201106050353.wav 72000 -0.0 1.0
# CUT New length = 10000
# 90 ./audio/artifact__201105190800.wav 72000 0.0 1.0
# CUT New length = 10000
# 91 ./audio/Aunlabelledtest__201104012144.wav 45693 0.0 1.0
# CUT New length = 10000
# 92 ./audio/murmur__201102052338.wav 72000 -0.0 1.0
# CUT New length = 10000
# 93 ./audio/Aunlabelledtest__201103140236.wav 72000 -0.0 0.99999994
# CUT New length = 10000
# 94 ./audio/Aunlabelledtest__201101152256.wav 62890 -0.0 1.0
# CUT New length = 10000
# 95 ./audio/murmur__201108222233.wav 63485 -0.0 0.9999999
# CUT New length = 10000
# 96 ./audio/Aunlabelledtest__201102081033.wav 57026 -0.0 0.99999994
# CUT New length = 10000
# 97 ./audio/artifact__201106010559.wav 72000 -0.0 1.0
# CUT New length = 10000
# 98 ./audio/Aunlabelledtest__201108222241.wav 63485 -0.0 1.0
# CUT New length = 10000
# 99 ./audio/artifact__201106021541.wav 72000 -0.0 0.99999994
# CUT New length = 10000
# 100 ./audio/Aunlabelledtest__201108222228.wav 63485 -0.0 0.99999994
# CUT New length = 10000
# 101 ./audio/extrahls__201103182227.wav 72000 -0.0 1.0
# CUT New length = 10000
# 102 ./audio/normal__201102081152.wav 57159 -0.0 1.0
# CUT New length = 10000
# 103 ./audio/artifact__201012172012.wav 72000 0.0 0.9999999
# CUT New length = 10000
# 104 ./audio/Aunlabelledtest__201012172010.wav 72000 0.0 1.0
# CUT New length = 10000
# 105 ./audio/normal__201103140135.wav 63577 -0.0 0.99999994
# CUT New length = 10000
# 106 ./audio/Aunlabelledtest__201106040930.wav 72000 -0.0 1.0
# CUT New length = 10000
# 107 ./audio/artifact__201106101955.wav 72000 0.0 1.0
# CUT New length = 10000
# 108 ./audio/extrahls__201101070953.wav 71073 -0.0 1.0
# CUT New length = 10000
# 109 ./audio/extrahls__201101241433.wav 72000 -0.0 1.0
# CUT New length = 10000
# 110 ./audio/normal__201103140132.wav 72000 -0.0 0.9999999
# CUT New length = 10000
# 111 ./audio/normal__201108011115.wav 63485 0.0 0.99999994
# CUT New length = 10000
# 112 ./audio/normal__201106221418.wav 56023 -0.0 0.99999994
# CUT New length = 10000
# 113 ./audio/extrahls__201104270458.wav 25884 0.0 1.0
# CUT New length = 10000
# 114 ./audio/Aunlabelledtest__201108222244.wav 63485 -0.0 0.99999994
# CUT New length = 10000
# 115 ./audio/artifact__201106131834.wav 72000 0.0 0.99999994
# CUT New length = 10000
# 116 ./audio/artifact__201106121242.wav 72000 0.0 1.0
# CUT New length = 10000
# 117 ./audio/artifact__201106110909.wav 72000 0.0 0.99999994
# CUT New length = 10000
# 118 ./audio/Aunlabelledtest__201106120928.wav 72000 0.0 1.0
# CUT New length = 10000
# 119 ./audio/murmur__201108222235.wav 63485 -0.0 1.0
# CUT New length = 10000
# 120 ./audio/Aunlabelledtest__201103232251.wav 72000 -0.0 0.9999999
# CUT New length = 10000
# 121 ./audio/normal__201103101140.wav 72000 -0.0 0.99999994
# CUT New length = 10000
# 122 ./audio/artifact__201106211041.wav 72000 -0.0 1.0000001
# CUT New length = 10000
# 123 ./audio/murmur__201104241315.wav 72000 0.0 0.99999994
# CUT New length = 10000
# 124 ./audio/Aunlabelledtest__201103170122.wav 68925 0.0 0.99999994
# CUT New length = 10000
# 125 ./audio/normal__201105021654.wav 63978 -0.0 1.0
# CUT New length = 10000
# 126 ./audio/artifact__201106061233.wav 72000 -0.0 1.0
# CUT New length = 10000
# 127 ./audio/artifact__201106121445.wav 72000 0.0 0.9999999
# CUT New length = 10000
# 128 ./audio/artifact__201106221254.wav 72000 -0.0 1.0
# CUT New length = 10000
# 129 ./audio/extrahls__201102070251.wav 64112 -0.0 1.0
# CUT New length = 10000
# 130 ./audio/Aunlabelledtest__201101091156.wav 72000 0.0 1.0
# CUT New length = 10000
# 131 ./audio/Aunlabelledtest__201108222225.wav 63485 0.0 0.99999994
# CUT New length = 10000
# 132 ./audio/extrahls__201103170134.wav 63042 0.0 1.0
# CUT New length = 10000
# 133 ./audio/Aunlabelledtest__201101220549.wav 72000 0.0 1.0
# CUT New length = 10000
# 134 ./audio/normal__201103221214.wav 27708 0.0 0.99999994
# CUT New length = 10000
# 135 ./audio/normal__201105011626.wav 72000 -0.0 1.0
# CUT New length = 10000
# 136 ./audio/murmur__201108222253.wav 63485 0.0 1.0
# CUT New length = 10000
# 137 ./audio/artifact__201106040947.wav 72000 0.0 1.0
# CUT New length = 10000
# 138 ./audio/Aunlabelledtest__201106171155.wav 72000 0.0 0.99999994
# CUT New length = 10000
# 139 ./audio/murmur__201108222224.wav 63485 0.0 0.99999994
# CUT New length = 10000
# 140 ./audio/extrahls__201102241217.wav 72000 0.0 1.0
# CUT New length = 10000
# 141 ./audio/artifact__201106211430.wav 72000 -0.0 1.0
# CUT New length = 10000
# 142 ./audio/murmur__201108222242.wav 63485 -0.0 1.0
# CUT New length = 10000
# 143 ./audio/artifact__201105041959.wav 72000 -0.0 0.99999994
# CUT New length = 10000
# 144 ./audio/artifact__201106212112.wav 72000 -0.0 1.0
# CUT New length = 10000
# 145 ./audio/artifact__201106141701.wav 72000 0.0 0.99999994
# CUT New length = 10000
# 146 ./audio/extrahls__201104021355.wav 7491 -0.0 1.0
# PAD New length = 10000
# 147 ./audio/normal__201106141148.wav 45995 -0.0 1.0
# CUT New length = 10000
# 148 ./audio/murmur__201102051443.wav 54552 0.0 1.0
# CUT New length = 10000
# 149 ./audio/normal__201108011114.wav 63485 -0.0 1.0
# CUT New length = 10000
# 150 ./audio/artifact__201106161019.wav 72000 -0.0 1.0
# CUT New length = 10000
# 151 ./audio/artifact__201106131835.wav 72000 0.0 1.0
# CUT New length = 10000
# 152 ./audio/murmur__201108222226.wav 63485 -0.0 1.0
# CUT New length = 10000
# 153 ./audio/normal__201106111136.wav 39711 0.0 1.0
# CUT New length = 10000
# 154 ./audio/Aunlabelledtest__201106061215.wav 72000 -0.0 1.0
# CUT New length = 10000
# 155 ./audio/Aunlabelledtest__201103200518.wav 68524 0.0 1.0
# CUT New length = 10000
# 156 ./audio/Aunlabelledtest__201102200848.wav 63778 -0.0 1.0
# CUT New length = 10000
# 157 ./audio/murmur__201108222256.wav 63485 -0.0 1.0
# CUT New length = 10000
# 158 ./audio/murmur__201101051104.wav 71073 -0.0 1.0
# CUT New length = 10000
# 159 ./audio/Aunlabelledtest__201103201314.wav 14040 -0.0 1.0
# CUT New length = 10000
# 160 ./audio/murmur__201108222237.wav 63485 -0.0 1.0
# CUT New length = 10000
# 161 ./audio/extrahls__201104270459.wav 13162 0.0 1.0
# CUT New length = 10000
# 162 ./audio/normal__201102260502.wav 50274 -0.0 1.0
# CUT New length = 10000
# 163 ./audio/normal__201102081321.wav 63109 0.0 1.0
# CUT New length = 10000
# 164 ./audio/murmur__201108222231.wav 63485 -0.0 1.0
# CUT New length = 10000
# 165 ./audio/artifact__201105060108.wav 72000 -0.0 1.0
# CUT New length = 10000
# 166 ./audio/Aunlabelledtest__2011040239.wav 30962 -0.0 0.99999994
# CUT New length = 10000
# 167 ./audio/artifact__201106040933.wav 72000 0.0 1.0
# CUT New length = 10000
# 168 ./audio/Aunlabelledtest__201106191034.wav 72000 0.0 0.99999994
# CUT New length = 10000
# 169 ./audio/Aunlabelledtest__201108222257.wav 63485 -0.0 1.0
# CUT New length = 10000
# 170 ./audio/murmur__201108222248.wav 63485 0.0 1.0
# CUT New length = 10000
# 171 ./audio/normal__201101070538.wav 71073 -0.0 1.0
# CUT New length = 10000
# 172 ./audio/artifact__201106161219.wav 72000 0.0 1.0
# CUT New length = 10000
# 173 ./audio/extrahls__201103150114.wav 72000 -0.0 1.0
# CUT New length = 10000
# 174 ./audio/Aunlabelledtest__201108011116.wav 63485 -0.0 1.0
# CUT New length = 10000
# 175 ./audio/murmur__201108222232.wav 63485 0.0 1.0
# CUT New length = 10000

# %% [markdown]
# ### Build the ConvNet Model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Lambda,Conv1D, MaxPooling1D,Activation, Dense,BatchNormalization

from tensorflow.keras.models import Sequential
import numpy as np
import pickle
import os
from glob import glob

# %%
AUDIO_LENGTH = 10000
OUTPUT_DIR = './output'
OUTPUT_DIR_TRAIN = os.path.join(OUTPUT_DIR, 'train')
OUTPUT_DIR_TEST = os.path.join(OUTPUT_DIR, 'test')

# %%
def m5(num_classes=5):
    print('Using Model M5')
    m = Sequential()
    m.add(Conv1D(128,
                 input_shape=[AUDIO_LENGTH, 1],
                 kernel_size=80,
                 strides=4,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Conv1D(128,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Conv1D(256,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Conv1D(512,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Lambda(lambda x: K.mean(x, axis=1)))  
    m.add(Dense(num_classes, activation='softmax'))
    return m

# %% [markdown]
# ### Custom Function - Get Data in Training Data and Label Format

# %%
def get_data(file_list):
    def load_into(_filename, _x, _y):
        with open(_filename, 'rb') as f:
            audio_element = pickle.load(f)
            _x.append(audio_element['audio'])
            _y.append(int(audio_element['class_id']))

    x, y = [], []
    for filename in file_list:
        load_into(filename, x, y)
    return np.array(x), np.array(y)

# %%
# Read Training data
train_files = glob(os.path.join(OUTPUT_DIR_TRAIN, '**.pkl'))
x_tr, y_tr = get_data(train_files)
y_tr = to_categorical(y_tr, num_classes=num_classes)

# Read Test Data
test_files = glob(os.path.join(OUTPUT_DIR_TEST, '**.pkl'))
x_te, y_te = get_data(test_files)
y_te = to_categorical(y_te, num_classes=num_classes)

print('x_tr.shape =', x_tr.shape)
print('y_tr.shape =', y_tr.shape)
print('x_te.shape =', x_te.shape)
print('y_te.shape =', y_te.shape)
# Out:
# x_tr.shape = (166, 10000, 1)
# y_tr.shape = (166, 5)
# x_te.shape = (10, 10000, 1)
# y_te.shape = (10, 5)

# %% [markdown]
# ## Create the CNN Object

# %%
num_classes = 5
model = m5(num_classes=num_classes)

if model is None:
    exit('Something went wrong!!')

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
print(model.summary())

# Define a callback
# if the accuracy does not increase over 10 epochs, reduce the learning rate by half.
reduce_lr = ReduceLROnPlateau(monitor='accuracy', factor=0.5, patience=10, min_lr=0.0001, verbose=1)

# Set a batch size
batch_size = 128
# Out:
# Using Model M5
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 2500, 128)         10368
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2500, 128)         512
# _________________________________________________________________
# activation_20 (Activation)   (None, 2500, 128)         0
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 625, 128)          0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 625, 128)          49280
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 625, 128)          512
# _________________________________________________________________
# activation_21 (Activation)   (None, 625, 128)          0
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 156, 128)          0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 156, 256)          98560
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 156, 256)          1024
# _________________________________________________________________
# activation_22 (Activation)   (None, 156, 256)          0
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 39, 256)           0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 39, 512)           393728
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 39, 512)           2048
# _________________________________________________________________
# activation_23 (Activation)   (None, 39, 512)           0
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 9, 512)            0
# _________________________________________________________________
# lambda_5 (Lambda)            (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 558,597
# Trainable params: 556,549
# Non-trainable params: 2,048
# _________________________________________________________________
# None

# %% [markdown]
# ## Train the CNN with Validation Data

# %%
# Train the model
model.fit(x=x_tr,
          y=y_tr,
          batch_size=batch_size,
          epochs=250,
          verbose=1,
          shuffle=True,
          validation_data=(x_te, y_te),
          callbacks=[reduce_lr])
# Out:
# Epoch 1/250
# 2/2 [==============================] - 0s 128ms/step - loss: 0.1294 - accuracy: 0.9578 - val_loss: 1.6136 - val_accuracy: 0.4000
# Epoch 2/250
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1325 - accuracy: 0.9578 - val_loss: 1.3400 - val_accuracy: 0.5000
# Epoch 3/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1256 - accuracy: 0.9639 - val_loss: 1.1950 - val_accuracy: 0.6000
# Epoch 4/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1221 - accuracy: 0.9819 - val_loss: 1.1825 - val_accuracy: 0.6000
# Epoch 5/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1228 - accuracy: 0.9759 - val_loss: 1.1979 - val_accuracy: 0.6000
# Epoch 6/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1244 - accuracy: 0.9759 - val_loss: 1.2311 - val_accuracy: 0.6000
# Epoch 7/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1250 - accuracy: 0.9699 - val_loss: 1.2248 - val_accuracy: 0.6000
# Epoch 8/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1208 - accuracy: 0.9759 - val_loss: 1.1959 - val_accuracy: 0.6000
# Epoch 9/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1236 - accuracy: 0.9699 - val_loss: 1.2024 - val_accuracy: 0.6000
# Epoch 10/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1229 - accuracy: 0.9639 - val_loss: 1.3276 - val_accuracy: 0.6000
# Epoch 11/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1218 - accuracy: 0.9819 - val_loss: 1.5483 - val_accuracy: 0.4000
# Epoch 12/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1265 - accuracy: 0.9639 - val_loss: 1.5510 - val_accuracy: 0.4000
# Epoch 13/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1262 - accuracy: 0.9639 - val_loss: 1.3425 - val_accuracy: 0.5000
# Epoch 14/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1175 - accuracy: 0.9759 - val_loss: 1.2664 - val_accuracy: 0.6000
# Epoch 15/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1246 - accuracy: 0.9639 - val_loss: 1.2699 - val_accuracy: 0.6000
# Epoch 16/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1204 - accuracy: 0.9699 - val_loss: 1.4160 - val_accuracy: 0.5000
# Epoch 17/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1235 - accuracy: 0.9699 - val_loss: 1.4875 - val_accuracy: 0.5000
# Epoch 18/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1243 - accuracy: 0.9578 - val_loss: 1.4102 - val_accuracy: 0.5000
# Epoch 19/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1209 - accuracy: 0.9819 - val_loss: 1.3100 - val_accuracy: 0.5000
# Epoch 20/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1219 - accuracy: 0.9699 - val_loss: 1.2554 - val_accuracy: 0.6000
# Epoch 21/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1277 - accuracy: 0.9578 - val_loss: 1.3361 - val_accuracy: 0.5000
# Epoch 22/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1235 - accuracy: 0.9819 - val_loss: 1.6162 - val_accuracy: 0.4000
# Epoch 23/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1276 - accuracy: 0.9639 - val_loss: 1.7039 - val_accuracy: 0.4000
# Epoch 24/250
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1286 - accuracy: 0.9518 - val_loss: 1.6049 - val_accuracy: 0.5000
# Epoch 25/250
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1237 - accuracy: 0.9639 - val_loss: 1.4218 - val_accuracy: 0.5000
# Epoch 26/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1205 - accuracy: 0.9819 - val_loss: 1.3652 - val_accuracy: 0.6000
# Epoch 27/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1238 - accuracy: 0.9699 - val_loss: 1.3741 - val_accuracy: 0.6000
# Epoch 28/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1276 - accuracy: 0.9639 - val_loss: 1.3439 - val_accuracy: 0.6000
# Epoch 29/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1225 - accuracy: 0.9699 - val_loss: 1.4843 - val_accuracy: 0.5000
# Epoch 30/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1223 - accuracy: 0.9759 - val_loss: 1.6329 - val_accuracy: 0.5000
# Epoch 31/250
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1224 - accuracy: 0.9639 - val_loss: 1.6213 - val_accuracy: 0.5000
# Epoch 32/250
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1291 - accuracy: 0.9639 - val_loss: 1.5069 - val_accuracy: 0.5000
# Epoch 33/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1199 - accuracy: 0.9819 - val_loss: 1.4571 - val_accuracy: 0.5000
# Epoch 34/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1210 - accuracy: 0.9819 - val_loss: 1.3643 - val_accuracy: 0.5000
# Epoch 35/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1187 - accuracy: 0.9819 - val_loss: 1.2132 - val_accuracy: 0.6000
# Epoch 36/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1192 - accuracy: 0.9880 - val_loss: 1.1432 - val_accuracy: 0.7000
# Epoch 37/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1230 - accuracy: 0.9699 - val_loss: 1.1173 - val_accuracy: 0.6000
# Epoch 38/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1226 - accuracy: 0.9639 - val_loss: 1.1590 - val_accuracy: 0.7000
# Epoch 39/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1215 - accuracy: 0.9639 - val_loss: 1.2729 - val_accuracy: 0.4000
# Epoch 40/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1145 - accuracy: 0.9699 - val_loss: 1.3187 - val_accuracy: 0.5000
# Epoch 41/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1195 - accuracy: 0.9699 - val_loss: 1.3462 - val_accuracy: 0.5000
# Epoch 42/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1188 - accuracy: 0.9759 - val_loss: 1.3575 - val_accuracy: 0.4000
# Epoch 43/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1187 - accuracy: 0.9759 - val_loss: 1.2616 - val_accuracy: 0.5000
# Epoch 44/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1163 - accuracy: 0.9819 - val_loss: 1.1970 - val_accuracy: 0.5000
# Epoch 45/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1127 - accuracy: 0.9880 - val_loss: 1.1462 - val_accuracy: 0.7000
# Epoch 46/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1220 - accuracy: 0.9699 - val_loss: 1.1154 - val_accuracy: 0.7000
# Epoch 47/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1212 - accuracy: 0.9699 - val_loss: 1.0795 - val_accuracy: 0.7000
# Epoch 48/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1254 - accuracy: 0.9639 - val_loss: 1.0831 - val_accuracy: 0.7000
# Epoch 49/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1199 - accuracy: 0.9759 - val_loss: 1.2728 - val_accuracy: 0.6000
# Epoch 50/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1192 - accuracy: 0.9759 - val_loss: 1.3919 - val_accuracy: 0.5000
# Epoch 51/250
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1214 - accuracy: 0.9639 - val_loss: 1.2956 - val_accuracy: 0.6000
# Epoch 52/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1172 - accuracy: 0.9759 - val_loss: 1.1891 - val_accuracy: 0.5000
# Epoch 53/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1297 - accuracy: 0.9819 - val_loss: 1.0784 - val_accuracy: 0.7000
# Epoch 54/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1211 - accuracy: 0.9639 - val_loss: 1.0940 - val_accuracy: 0.7000
# Epoch 55/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1201 - accuracy: 0.9699 - val_loss: 1.2842 - val_accuracy: 0.5000
# Epoch 56/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1190 - accuracy: 0.9819 - val_loss: 1.6497 - val_accuracy: 0.5000
# Epoch 57/250
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1252 - accuracy: 0.9639 - val_loss: 1.6188 - val_accuracy: 0.4000
# Epoch 58/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1204 - accuracy: 0.9639 - val_loss: 1.3335 - val_accuracy: 0.5000
# Epoch 59/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1141 - accuracy: 0.9819 - val_loss: 1.2029 - val_accuracy: 0.7000
# Epoch 60/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1200 - accuracy: 0.9699 - val_loss: 1.2127 - val_accuracy: 0.6000
# Epoch 61/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1176 - accuracy: 0.9819 - val_loss: 1.3586 - val_accuracy: 0.5000
# Epoch 62/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1196 - accuracy: 0.9699 - val_loss: 1.4156 - val_accuracy: 0.4000
# Epoch 63/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1205 - accuracy: 0.9639 - val_loss: 1.3006 - val_accuracy: 0.6000
# Epoch 64/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1182 - accuracy: 0.9819 - val_loss: 1.2246 - val_accuracy: 0.5000
# Epoch 65/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1186 - accuracy: 0.9819 - val_loss: 1.1922 - val_accuracy: 0.6000
# Epoch 66/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1173 - accuracy: 0.9759 - val_loss: 1.2096 - val_accuracy: 0.6000
# Epoch 67/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1118 - accuracy: 0.9819 - val_loss: 1.2874 - val_accuracy: 0.6000
# Epoch 68/250
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1172 - accuracy: 0.9639 - val_loss: 1.2428 - val_accuracy: 0.6000
# Epoch 69/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1224 - accuracy: 0.9819 - val_loss: 1.1346 - val_accuracy: 0.6000
# Epoch 70/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1210 - accuracy: 0.9699 - val_loss: 1.1386 - val_accuracy: 0.6000
# Epoch 71/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1163 - accuracy: 0.9699 - val_loss: 1.4856 - val_accuracy: 0.5000
# Epoch 72/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1217 - accuracy: 0.9699 - val_loss: 2.0266 - val_accuracy: 0.3000
# Epoch 73/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1356 - accuracy: 0.9578 - val_loss: 1.6907 - val_accuracy: 0.4000
# Epoch 74/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1263 - accuracy: 0.9578 - val_loss: 1.2481 - val_accuracy: 0.5000
# Epoch 75/250
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1213 - accuracy: 0.9699 - val_loss: 1.1822 - val_accuracy: 0.7000
# Epoch 76/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1304 - accuracy: 0.9578 - val_loss: 1.1820 - val_accuracy: 0.7000
# Epoch 77/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1272 - accuracy: 0.9639 - val_loss: 1.2878 - val_accuracy: 0.5000
# Epoch 78/250
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1242 - accuracy: 0.9639 - val_loss: 1.5827 - val_accuracy: 0.4000
# Epoch 79/250
# 2/2 [==============================] - 0s 92ms/step - loss: 0.1187 - accuracy: 0.9819 - val_loss: 1.8087 - val_accuracy: 0.4000
# Epoch 80/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1266 - accuracy: 0.9578 - val_loss: 1.8450 - val_accuracy: 0.4000
# Epoch 81/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1249 - accuracy: 0.9699 - val_loss: 1.5396 - val_accuracy: 0.5000
# Epoch 82/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1155 - accuracy: 0.9819 - val_loss: 1.2568 - val_accuracy: 0.6000
# Epoch 83/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1175 - accuracy: 0.9819 - val_loss: 1.0774 - val_accuracy: 0.8000
# Epoch 84/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1199 - accuracy: 0.9699 - val_loss: 1.0288 - val_accuracy: 0.6000
# Epoch 85/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1197 - accuracy: 0.9699 - val_loss: 1.0455 - val_accuracy: 0.7000
# Epoch 86/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1184 - accuracy: 0.9759 - val_loss: 1.1844 - val_accuracy: 0.5000
# Epoch 87/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1187 - accuracy: 0.9759 - val_loss: 1.3406 - val_accuracy: 0.4000
# Epoch 88/250
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1212 - accuracy: 0.9639 - val_loss: 1.3295 - val_accuracy: 0.5000
# Epoch 89/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1215 - accuracy: 0.9639 - val_loss: 1.2159 - val_accuracy: 0.5000
# Epoch 90/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1189 - accuracy: 0.9639 - val_loss: 1.1359 - val_accuracy: 0.7000
# Epoch 91/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1145 - accuracy: 0.9759 - val_loss: 1.1321 - val_accuracy: 0.7000
# Epoch 92/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1175 - accuracy: 0.9819 - val_loss: 1.1652 - val_accuracy: 0.6000
# Epoch 93/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1190 - accuracy: 0.9699 - val_loss: 1.2793 - val_accuracy: 0.5000
# Epoch 94/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1226 - accuracy: 0.9699 - val_loss: 1.5427 - val_accuracy: 0.5000
# Epoch 95/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1176 - accuracy: 0.9819 - val_loss: 1.7929 - val_accuracy: 0.4000
# Epoch 96/250
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1152 - accuracy: 0.9819 - val_loss: 1.9669 - val_accuracy: 0.4000
# Epoch 97/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1175 - accuracy: 0.9759 - val_loss: 1.9955 - val_accuracy: 0.4000
# Epoch 98/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1174 - accuracy: 0.9819 - val_loss: 1.7962 - val_accuracy: 0.5000
# Epoch 99/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1143 - accuracy: 0.9759 - val_loss: 1.5774 - val_accuracy: 0.5000
# Epoch 100/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1172 - accuracy: 0.9819 - val_loss: 1.4661 - val_accuracy: 0.5000
# Epoch 101/250
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1182 - accuracy: 0.9759 - val_loss: 1.4692 - val_accuracy: 0.6000
# Epoch 102/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1145 - accuracy: 0.9819 - val_loss: 1.4666 - val_accuracy: 0.6000
# Epoch 103/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1175 - accuracy: 0.9699 - val_loss: 1.4387 - val_accuracy: 0.6000
# Epoch 104/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1159 - accuracy: 0.9759 - val_loss: 1.4655 - val_accuracy: 0.5000
# Epoch 105/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1148 - accuracy: 0.9759 - val_loss: 1.6650 - val_accuracy: 0.5000
# Epoch 106/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1307 - accuracy: 0.9578 - val_loss: 1.6163 - val_accuracy: 0.5000
# Epoch 107/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1175 - accuracy: 0.9639 - val_loss: 1.3101 - val_accuracy: 0.6000
# Epoch 108/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1213 - accuracy: 0.9699 - val_loss: 1.2383 - val_accuracy: 0.6000
# Epoch 109/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1200 - accuracy: 0.9699 - val_loss: 1.2614 - val_accuracy: 0.6000
# Epoch 110/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1229 - accuracy: 0.9759 - val_loss: 1.4376 - val_accuracy: 0.5000
# Epoch 111/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1152 - accuracy: 0.9819 - val_loss: 1.5389 - val_accuracy: 0.4000
# Epoch 112/250
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1158 - accuracy: 0.9759 - val_loss: 1.5272 - val_accuracy: 0.4000
# Epoch 113/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1135 - accuracy: 0.9819 - val_loss: 1.6299 - val_accuracy: 0.4000
# Epoch 114/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1178 - accuracy: 0.9819 - val_loss: 1.6512 - val_accuracy: 0.4000
# Epoch 115/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1169 - accuracy: 0.9639 - val_loss: 1.4481 - val_accuracy: 0.5000
# Epoch 116/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1152 - accuracy: 0.9819 - val_loss: 1.2895 - val_accuracy: 0.7000
# Epoch 117/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1205 - accuracy: 0.9639 - val_loss: 1.2902 - val_accuracy: 0.6000
# Epoch 118/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1207 - accuracy: 0.9699 - val_loss: 1.3917 - val_accuracy: 0.6000
# Epoch 119/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1133 - accuracy: 0.9819 - val_loss: 1.5150 - val_accuracy: 0.5000
# Epoch 120/250
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1204 - accuracy: 0.9759 - val_loss: 1.5908 - val_accuracy: 0.5000
# Epoch 121/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1134 - accuracy: 0.9759 - val_loss: 1.4743 - val_accuracy: 0.5000
# Epoch 122/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1124 - accuracy: 0.9819 - val_loss: 1.3576 - val_accuracy: 0.6000
# Epoch 123/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1133 - accuracy: 0.9819 - val_loss: 1.3330 - val_accuracy: 0.6000
# Epoch 124/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1147 - accuracy: 0.9819 - val_loss: 1.3386 - val_accuracy: 0.6000
# Epoch 125/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1128 - accuracy: 0.9759 - val_loss: 1.3272 - val_accuracy: 0.6000
# Epoch 126/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1131 - accuracy: 0.9819 - val_loss: 1.4360 - val_accuracy: 0.6000
# Epoch 127/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1109 - accuracy: 0.9759 - val_loss: 1.6207 - val_accuracy: 0.3000
# Epoch 128/250
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1196 - accuracy: 0.9639 - val_loss: 1.5478 - val_accuracy: 0.5000
# Epoch 129/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1154 - accuracy: 0.9699 - val_loss: 1.2974 - val_accuracy: 0.6000
# Epoch 130/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1163 - accuracy: 0.9819 - val_loss: 1.2889 - val_accuracy: 0.6000
# Epoch 131/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1229 - accuracy: 0.9639 - val_loss: 1.5950 - val_accuracy: 0.5000
# Epoch 132/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1183 - accuracy: 0.9699 - val_loss: 1.9832 - val_accuracy: 0.4000
# Epoch 133/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1129 - accuracy: 0.9819 - val_loss: 2.1062 - val_accuracy: 0.3000
# Epoch 134/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1209 - accuracy: 0.9759 - val_loss: 1.8461 - val_accuracy: 0.5000
# Epoch 135/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1139 - accuracy: 0.9699 - val_loss: 1.5688 - val_accuracy: 0.5000
# Epoch 136/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1222 - accuracy: 0.9639 - val_loss: 1.5291 - val_accuracy: 0.6000
# Epoch 137/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1228 - accuracy: 0.9639 - val_loss: 1.5380 - val_accuracy: 0.5000
# Epoch 138/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1126 - accuracy: 0.9819 - val_loss: 1.6745 - val_accuracy: 0.5000
# Epoch 139/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1119 - accuracy: 0.9759 - val_loss: 1.9239 - val_accuracy: 0.3000
# Epoch 140/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1121 - accuracy: 0.9699 - val_loss: 1.8927 - val_accuracy: 0.4000
# Epoch 141/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1114 - accuracy: 0.9759 - val_loss: 1.6299 - val_accuracy: 0.4000
# Epoch 142/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1102 - accuracy: 0.9819 - val_loss: 1.3736 - val_accuracy: 0.6000
# Epoch 143/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1180 - accuracy: 0.9699 - val_loss: 1.4124 - val_accuracy: 0.5000
# Epoch 144/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1146 - accuracy: 0.9699 - val_loss: 1.7281 - val_accuracy: 0.3000
# Epoch 145/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1110 - accuracy: 0.9819 - val_loss: 1.8442 - val_accuracy: 0.3000
# Epoch 146/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1177 - accuracy: 0.9759 - val_loss: 1.7249 - val_accuracy: 0.4000
# Epoch 147/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1162 - accuracy: 0.9699 - val_loss: 1.5263 - val_accuracy: 0.4000
# Epoch 148/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1190 - accuracy: 0.9759 - val_loss: 1.3638 - val_accuracy: 0.5000
# Epoch 149/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1168 - accuracy: 0.9819 - val_loss: 1.2921 - val_accuracy: 0.6000
# Epoch 150/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1177 - accuracy: 0.9819 - val_loss: 1.2819 - val_accuracy: 0.6000
# Epoch 151/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1171 - accuracy: 0.9819 - val_loss: 1.3265 - val_accuracy: 0.5000
# Epoch 152/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1120 - accuracy: 0.9819 - val_loss: 1.4859 - val_accuracy: 0.4000
# Epoch 153/250
# 2/2 [==============================] - 0s 101ms/step - loss: 0.1101 - accuracy: 0.9819 - val_loss: 1.6428 - val_accuracy: 0.4000
# Epoch 154/250
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1151 - accuracy: 0.9578 - val_loss: 1.6257 - val_accuracy: 0.4000
# Epoch 155/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1144 - accuracy: 0.9639 - val_loss: 1.4430 - val_accuracy: 0.5000
# Epoch 156/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1094 - accuracy: 0.9819 - val_loss: 1.3248 - val_accuracy: 0.6000
# Epoch 157/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1118 - accuracy: 0.9819 - val_loss: 1.4021 - val_accuracy: 0.6000
# Epoch 158/250
# 2/2 [==============================] - 0s 99ms/step - loss: 0.1095 - accuracy: 0.9759 - val_loss: 1.6382 - val_accuracy: 0.4000
# Epoch 159/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1110 - accuracy: 0.9759 - val_loss: 1.6450 - val_accuracy: 0.4000
# Epoch 160/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1116 - accuracy: 0.9759 - val_loss: 1.5761 - val_accuracy: 0.5000
# Epoch 161/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1092 - accuracy: 0.9819 - val_loss: 1.5602 - val_accuracy: 0.5000
# Epoch 162/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1095 - accuracy: 0.9819 - val_loss: 1.5286 - val_accuracy: 0.5000
# Epoch 163/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1107 - accuracy: 0.9819 - val_loss: 1.5761 - val_accuracy: 0.5000
# Epoch 164/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1137 - accuracy: 0.9759 - val_loss: 1.7647 - val_accuracy: 0.3000
# Epoch 165/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1129 - accuracy: 0.9699 - val_loss: 1.5822 - val_accuracy: 0.3000
# Epoch 166/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1116 - accuracy: 0.9819 - val_loss: 1.3328 - val_accuracy: 0.6000
# Epoch 167/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1170 - accuracy: 0.9699 - val_loss: 1.6196 - val_accuracy: 0.3000
# Epoch 168/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1104 - accuracy: 0.9759 - val_loss: 2.2835 - val_accuracy: 0.3000
# Epoch 169/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1236 - accuracy: 0.9578 - val_loss: 2.2133 - val_accuracy: 0.3000
# Epoch 170/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1134 - accuracy: 0.9639 - val_loss: 1.6023 - val_accuracy: 0.4000
# Epoch 171/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1128 - accuracy: 0.9759 - val_loss: 1.2398 - val_accuracy: 0.6000
# Epoch 172/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1244 - accuracy: 0.9578 - val_loss: 1.2834 - val_accuracy: 0.6000
# Epoch 173/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1177 - accuracy: 0.9699 - val_loss: 1.6985 - val_accuracy: 0.3000
# Epoch 174/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1126 - accuracy: 0.9819 - val_loss: 2.3782 - val_accuracy: 0.3000
# Epoch 175/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1122 - accuracy: 0.9639 - val_loss: 2.9116 - val_accuracy: 0.3000
# Epoch 176/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1218 - accuracy: 0.9639 - val_loss: 2.9665 - val_accuracy: 0.3000
# Epoch 177/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1273 - accuracy: 0.9639 - val_loss: 2.3882 - val_accuracy: 0.3000
# Epoch 178/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1161 - accuracy: 0.9699 - val_loss: 1.7299 - val_accuracy: 0.4000
# Epoch 179/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1137 - accuracy: 0.9699 - val_loss: 1.3164 - val_accuracy: 0.5000
# Epoch 180/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1155 - accuracy: 0.9819 - val_loss: 1.1817 - val_accuracy: 0.6000
# Epoch 181/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1143 - accuracy: 0.9759 - val_loss: 1.1470 - val_accuracy: 0.6000
# Epoch 182/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1194 - accuracy: 0.9699 - val_loss: 1.3722 - val_accuracy: 0.5000
# Epoch 183/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1147 - accuracy: 0.9759 - val_loss: 1.9566 - val_accuracy: 0.3000
# Epoch 184/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1125 - accuracy: 0.9819 - val_loss: 2.4293 - val_accuracy: 0.4000
# Epoch 185/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1145 - accuracy: 0.9880 - val_loss: 2.6309 - val_accuracy: 0.4000
# Epoch 186/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1188 - accuracy: 0.9639 - val_loss: 2.3834 - val_accuracy: 0.4000
# Epoch 187/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1163 - accuracy: 0.9639 - val_loss: 1.7135 - val_accuracy: 0.4000
# Epoch 188/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1100 - accuracy: 0.9819 - val_loss: 1.2507 - val_accuracy: 0.6000
# Epoch 189/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1234 - accuracy: 0.9759 - val_loss: 1.1115 - val_accuracy: 0.7000
# Epoch 190/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1174 - accuracy: 0.9759 - val_loss: 1.0980 - val_accuracy: 0.6000
# Epoch 191/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1246 - accuracy: 0.9699 - val_loss: 1.1647 - val_accuracy: 0.5000
# Epoch 192/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1234 - accuracy: 0.9759 - val_loss: 1.5228 - val_accuracy: 0.4000
# Epoch 193/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1127 - accuracy: 0.9819 - val_loss: 2.1762 - val_accuracy: 0.3000
# Epoch 194/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1191 - accuracy: 0.9639 - val_loss: 2.2884 - val_accuracy: 0.3000
# Epoch 195/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1212 - accuracy: 0.9578 - val_loss: 1.9368 - val_accuracy: 0.3000
# Epoch 196/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1095 - accuracy: 0.9759 - val_loss: 1.7924 - val_accuracy: 0.5000
# Epoch 197/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1131 - accuracy: 0.9819 - val_loss: 1.6690 - val_accuracy: 0.5000
# Epoch 198/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1139 - accuracy: 0.9819 - val_loss: 1.5783 - val_accuracy: 0.5000
# Epoch 199/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1158 - accuracy: 0.9819 - val_loss: 1.5772 - val_accuracy: 0.5000
# Epoch 200/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1139 - accuracy: 0.9819 - val_loss: 1.6830 - val_accuracy: 0.5000
# Epoch 201/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1193 - accuracy: 0.9819 - val_loss: 1.9493 - val_accuracy: 0.3000
# Epoch 202/250
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1143 - accuracy: 0.9699 - val_loss: 2.2206 - val_accuracy: 0.3000
# Epoch 203/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1160 - accuracy: 0.9639 - val_loss: 1.9835 - val_accuracy: 0.3000
# Epoch 204/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1123 - accuracy: 0.9699 - val_loss: 1.5621 - val_accuracy: 0.6000
# Epoch 205/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1087 - accuracy: 0.9819 - val_loss: 1.4145 - val_accuracy: 0.5000
# Epoch 206/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1165 - accuracy: 0.9759 - val_loss: 1.4231 - val_accuracy: 0.5000
# Epoch 207/250
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1183 - accuracy: 0.9699 - val_loss: 1.4931 - val_accuracy: 0.5000
# Epoch 208/250
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1171 - accuracy: 0.9699 - val_loss: 1.7525 - val_accuracy: 0.4000
# Epoch 209/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1119 - accuracy: 0.9819 - val_loss: 2.0159 - val_accuracy: 0.4000
# Epoch 210/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1135 - accuracy: 0.9759 - val_loss: 2.1338 - val_accuracy: 0.3000
# Epoch 211/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1110 - accuracy: 0.9759 - val_loss: 2.0918 - val_accuracy: 0.4000
# Epoch 212/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1112 - accuracy: 0.9819 - val_loss: 1.8835 - val_accuracy: 0.4000
# Epoch 213/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1094 - accuracy: 0.9880 - val_loss: 1.6227 - val_accuracy: 0.4000
# Epoch 214/250
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1099 - accuracy: 0.9819 - val_loss: 1.4526 - val_accuracy: 0.4000
# Epoch 215/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1113 - accuracy: 0.9819 - val_loss: 1.3727 - val_accuracy: 0.4000
# Epoch 216/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1108 - accuracy: 0.9819 - val_loss: 1.3874 - val_accuracy: 0.4000
# Epoch 217/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1114 - accuracy: 0.9819 - val_loss: 1.4376 - val_accuracy: 0.4000
# Epoch 218/250
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1092 - accuracy: 0.9819 - val_loss: 1.5026 - val_accuracy: 0.5000
# Epoch 219/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1090 - accuracy: 0.9759 - val_loss: 1.6070 - val_accuracy: 0.5000
# Epoch 220/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1108 - accuracy: 0.9639 - val_loss: 1.5737 - val_accuracy: 0.5000
# Epoch 221/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1105 - accuracy: 0.9639 - val_loss: 1.4223 - val_accuracy: 0.5000
# Epoch 222/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1074 - accuracy: 0.9819 - val_loss: 1.3476 - val_accuracy: 0.4000
# Epoch 223/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1099 - accuracy: 0.9819 - val_loss: 1.3680 - val_accuracy: 0.4000
# Epoch 224/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1077 - accuracy: 0.9819 - val_loss: 1.4023 - val_accuracy: 0.4000
# Epoch 225/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1111 - accuracy: 0.9759 - val_loss: 1.3954 - val_accuracy: 0.4000
# Epoch 226/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1073 - accuracy: 0.9819 - val_loss: 1.4092 - val_accuracy: 0.4000
# Epoch 227/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1088 - accuracy: 0.9819 - val_loss: 1.5767 - val_accuracy: 0.5000
# Epoch 228/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1091 - accuracy: 0.9819 - val_loss: 1.7816 - val_accuracy: 0.5000
# Epoch 229/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1083 - accuracy: 0.9819 - val_loss: 1.9460 - val_accuracy: 0.5000
# Epoch 230/250
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1106 - accuracy: 0.9759 - val_loss: 1.8892 - val_accuracy: 0.5000
# Epoch 231/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1082 - accuracy: 0.9819 - val_loss: 1.6960 - val_accuracy: 0.5000
# Epoch 232/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1101 - accuracy: 0.9819 - val_loss: 1.5482 - val_accuracy: 0.5000
# Epoch 233/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1098 - accuracy: 0.9819 - val_loss: 1.5612 - val_accuracy: 0.5000
# Epoch 234/250
# 2/2 [==============================] - 0s 97ms/step - loss: 0.1074 - accuracy: 0.9819 - val_loss: 1.6275 - val_accuracy: 0.5000
# Epoch 235/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1072 - accuracy: 0.9819 - val_loss: 1.5749 - val_accuracy: 0.5000
# Epoch 236/250
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1084 - accuracy: 0.9819 - val_loss: 1.5314 - val_accuracy: 0.5000
# Epoch 237/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1076 - accuracy: 0.9819 - val_loss: 1.5162 - val_accuracy: 0.5000
# Epoch 238/250
# 2/2 [==============================] - 0s 95ms/step - loss: 0.1061 - accuracy: 0.9819 - val_loss: 1.5754 - val_accuracy: 0.5000
# Epoch 239/250
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1037 - accuracy: 0.9819 - val_loss: 1.6040 - val_accuracy: 0.5000
# Epoch 240/250
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1055 - accuracy: 0.9819 - val_loss: 1.5706 - val_accuracy: 0.5000
# Epoch 241/250
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1072 - accuracy: 0.9819 - val_loss: 1.6263 - val_accuracy: 0.5000
# Epoch 242/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1057 - accuracy: 0.9819 - val_loss: 1.8127 - val_accuracy: 0.5000
# Epoch 243/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1152 - accuracy: 0.9759 - val_loss: 1.8763 - val_accuracy: 0.5000
# Epoch 244/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1185 - accuracy: 0.9699 - val_loss: 1.7148 - val_accuracy: 0.5000
# Epoch 245/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1157 - accuracy: 0.9819 - val_loss: 1.3809 - val_accuracy: 0.5000
# Epoch 246/250
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1148 - accuracy: 0.9819 - val_loss: 1.4618 - val_accuracy: 0.5000
# Epoch 247/250
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1153 - accuracy: 0.9699 - val_loss: 1.5124 - val_accuracy: 0.5000
# Epoch 248/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1056 - accuracy: 0.9819 - val_loss: 1.4063 - val_accuracy: 0.5000
# Epoch 249/250
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1081 - accuracy: 0.9819 - val_loss: 1.3364 - val_accuracy: 0.6000
# Epoch 250/250
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1126 - accuracy: 0.9759 - val_loss: 1.4334 - val_accuracy: 0.5000
